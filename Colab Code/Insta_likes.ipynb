# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('insta_likes_data.xlsx')
data
# Out:
#           instagram name           influencer name   \
# 0                    433                        433
# 1          ____kimwoobin   á„€á…µá†·á„‹á…®á„‡á…µá†«
# 2           __youngbae__                    TAEYANG
# 3            _agentgirl_  ÐÐÐ¡Ð¢Ð¯ Ð˜Ð’Ð›Ð•Ð•Ð’Ð
# 4          _hakkencoser_              Hakken å…«çŠ¬
# ...                  ...                        ...
# 1017              zidane                     zidane
# 1018              zidane                     zidane
# 1019              zkdlin                        KAI
# 1020                  zo                 Lonzo Ball
# 1021  zoeisabellakravitz              ZoeÌˆ Kravitz
#
#                      Category_1   Category_2 Followers        Country   Likes  \
# 0            Sports with a ball         Null     50.7M          Spain  274.9K
# 1                     Lifestyle         Null      3.6M      Indonesia  449.4K
# 2                         Music         Null     13.4M      Indonesia  269.6K
# ...

# %%
def convert(column):
    if 'M' in column:
        return float(column.replace('M', '')) * 1000000
    elif 'K' in column:
        return float(column.replace('K', '')) * 1000
    else:
        return float(column)

# %%
data['Likes'] = data['Likes'].apply(convert)
data['Followers'] = data['Followers'].apply(convert)
data['Comments'] = data['Comments'].apply(convert)

# %%
data
# Out:
#           instagram name           influencer name   \
# 0                    433                        433
# 1          ____kimwoobin   á„€á…µá†·á„‹á…®á„‡á…µá†«
# 2           __youngbae__                    TAEYANG
# 3            _agentgirl_  ÐÐÐ¡Ð¢Ð¯ Ð˜Ð’Ð›Ð•Ð•Ð’Ð
# 4          _hakkencoser_              Hakken å…«çŠ¬
# ...                  ...                        ...
# 1017              zidane                     zidane
# 1018              zidane                     zidane
# 1019              zkdlin                        KAI
# 1020                  zo                 Lonzo Ball
# 1021  zoeisabellakravitz              ZoeÌˆ Kravitz
#
#                      Category_1   Category_2   Followers        Country  \
# 0            Sports with a ball         Null  50700000.0          Spain
# 1                     Lifestyle         Null   3600000.0      Indonesia
# 2                         Music         Null  13400000.0      Indonesia
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instagram name    1022 non-null   object
#  1   influencer name   996 non-null    object
#  2   Category_1        1022 non-null   object
#  3   Category_2        1022 non-null   object
#  4   Followers         1022 non-null   float64
#  5   Country           1022 non-null   object
#  6   Likes             1022 non-null   float64
#  7   Comments          1022 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 64.0+ KB

# %%
data_cat2 = data.drop(['Category_2'], axis=1)
data_cat2
# Out:
#           instagram name           influencer name   \
# 0                    433                        433
# 1          ____kimwoobin   á„€á…µá†·á„‹á…®á„‡á…µá†«
# 2           __youngbae__                    TAEYANG
# 3            _agentgirl_  ÐÐÐ¡Ð¢Ð¯ Ð˜Ð’Ð›Ð•Ð•Ð’Ð
# 4          _hakkencoser_              Hakken å…«çŠ¬
# ...                  ...                        ...
# 1017              zidane                     zidane
# 1018              zidane                     zidane
# 1019              zkdlin                        KAI
# 1020                  zo                 Lonzo Ball
# 1021  zoeisabellakravitz              ZoeÌˆ Kravitz
#
#                      Category_1   Followers        Country      Likes  \
# 0            Sports with a ball  50700000.0          Spain   274900.0
# 1                     Lifestyle   3600000.0      Indonesia   449400.0
# 2                         Music  13400000.0      Indonesia   269600.0
# ...

# %% [markdown]
# Top 5 Accounts with respect to Followers

# %%
max_followers = data_cat2.nlargest(5, 'Followers')
max_followers
# Out:
#     instagram name   influencer name           Category_1    Followers  \
# 395      instagram          Instagram         Photography  523300000.0
# 197      cristiano  Cristiano Ronaldo  Sports with a ball  459200000.0
# 524    kyliejenner         Kylie ðŸ¤             Fashion  352700000.0
# 548       leomessi          Leo Messi  Sports with a ball  341700000.0
# 825    selenagomez       Selena Gomez               Music  330600000.0
#
#            Country      Likes   Comments
# 395          India   294300.0   356500.0
# 197          India  5100000.0  6200000.0
# 524  United States  2800000.0  4600000.0
# 548      Argentina  4700000.0  6300000.0
# 825  United States  1200000.0  1600000.0

# %% [markdown]
# Top 5 Accounts with respect to Likes

# %%
max_Likes = data_cat2.nlargest(5, 'Likes')
max_Likes
# Out:
#     instagram name       influencer name    Category_1   Followers  \
# 920            thv                      V    Lifestyle  44800000.0
# 404            j.m                  JIMIN         Null  37000000.0
# 32          agustd  SUGA of BTS ë¯¼ìœ¤ê¸°    Lifestyle  35900000.0
# 940      uarmyhope                  jhope  Art/Artists  36600000.0
# 443            jin             Jin of BTS         Null  36600000.0
#
#            Country       Likes    Comments
# 920  United States  13200000.0  13200000.0
# 404          11.8M  11800000.0         0.0
# 32     1Unknown.2M  10200000.0         0.0
# 940    South Korea   9400000.0   9400000.0
# 443  United States   9300000.0   9300000.0

# %% [markdown]
# Top 5 Accounts with respect to Comments

# %%
max_comments = data_cat2.nlargest(5, 'Comments')
max_comments
# Out:
#       instagram name influencer name                  Category_1    Followers  \
# 920              thv                V                  Lifestyle   44800000.0
# 940        uarmyhope            jhope                Art/Artists   36600000.0
# 443              jin       Jin of BTS                       Null   36600000.0
# 1016         zendaya          Zendaya  Cinema & Actors/actresses  146300000.0
# 427   jennierubyjane                J                      Music   67600000.0
#
#             Country       Likes    Comments
# 920   United States  13200000.0  13200000.0
# 940     South Korea   9400000.0   9400000.0
# 443   United States   9300000.0   9300000.0
# 1016  United States   6300000.0   8500000.0
# 427       Indonesia   7000000.0   8400000.0

# %% [markdown]
# Unique Category

# %%
data_n = data[data['Category_1'] != 'Null']
print(data_n['Category_1'].nunique())
data_n['Category_1'].unique()
# Out:
# 31
# array(['Sports with a ball', 'Lifestyle', 'Music', 'Shows',
#        'Cinema & Actors/actresses', 'Humor & Fun & Happiness',
#        'Business & Careers', 'Beauty', 'Fashion', 'Food & Cooking',
#        'Family', 'Modeling', 'Finance & Economics', 'Photography',
#        'Art/Artists', 'Cars & Motorbikes', 'Fitness & Gym',
#        'Computers & Gadgets', 'Racing Sports', 'Animals',
#        'Literature & Journalism', 'Nature & landscapes', 'Adult content',
#        'Accessories & Jewellery', 'Extreme Sports & Outdoor activity',
#        'Education', 'Management & Marketing', 'Clothing & Outfits',
#        'Luxury', 'Science', 'Machinery & Technologies'], dtype=object)

# %%
data_n2 = data[data['Category_2'] != 'Null']
print(data_n2['Category_2'].nunique())
data_n2['Category_2'].unique()
# Out:
# 29
# array(['Photography', 'Cinema & Actors/actresses', 'Music', 'Lifestyle',
#        'Finance & Economics', 'Art/Artists', 'Literature & Journalism',
#        'Modeling', 'Shows', 'Beauty', 'Family', 'Humor & Fun & Happiness',
#        'Business & Careers', 'Travel', 'Fashion', 'Luxury',
#        'Racing Sports', 'Machinery & Technologies', 'Sports with a ball',
#        'Trainers & Coaches', 'Clothing & Outfits', 'Fitness & Gym',
#        'Cars & Motorbikes', 'Adult content', 'Comics & sketches',
#        'Science', 'Kids & Toys', 'Shopping & Retail',
#        'Computers & Gadgets'], dtype=object)

# %%
data_n3 = data[(data['Category_2'] != 'Null') & (data['Category_1'] != 'Null')]

# %% [markdown]
# Having 20cr followers

# %%
data_cat2[data_cat2['Followers'] >= 200_000_000]
# Out:
#       instagram name     influencer name                  Category_1  \
# 89      arianagrande        Ariana Grande                      Music
# 124          beyonce            BeyonceÌ                      Music
# 197        cristiano    Cristiano Ronaldo         Sports with a ball
# 395        instagram            Instagram                Photography
# 446              jlo       Jennifer Lopez                      Music
# 467     justinbieber        Justin Bieber                      Music
# 494    kendalljenner              Kendall                   Modeling
# 502  khloekardashian   KhloeÌ Kardashian         Clothing & Outfits
# 507    kimkardashian                  NaN                    Fashion
# 524      kyliejenner           Kylie ðŸ¤                    Fashion
# 548         leomessi            Leo Messi         Sports with a ball
# 671           natgeo  National Geographic        Nature & landscapes
# 698             nike                 Nike              Fitness & Gym
# ...

# %% [markdown]
# Group by category followers

# %% [markdown]
# Category vice followers sum

# %%
data_cat2.groupby('Category_1')['Followers'].sum().sort_values(ascending=False)
# Out:
# Category_1
# Music                                7.396000e+09
# Cinema & Actors/actresses            5.286600e+09
# Sports with a ball                   4.358100e+09
# Lifestyle                            1.748600e+09
# Modeling                             9.514000e+08
# Shows                                7.987000e+08
# Null                                 7.898000e+08
# Fashion                              7.628000e+08
# Photography                          5.768000e+08
# Beauty                               5.570000e+08
# Humor & Fun & Happiness              4.090000e+08
# Fitness & Gym                        3.603000e+08
# Clothing & Outfits                   3.093000e+08
# Nature & landscapes                  2.528000e+08
# Art/Artists                          2.268000e+08
# Finance & Economics                  2.206000e+08
# Family                               2.072000e+08
# Computers & Gadgets                  1.803000e+08
# ...

# %% [markdown]
# Top in perticular category

# %%
data_cat = data_n3[(data_n3['Category_2'] == 'Accessories & Jewellery') | (data_n3['Category_1'] == 'Accessories & Jewellery')]
data_cat.nlargest(5, 'Followers').drop_duplicates()
# Out:
#     instagram name influencer name                Category_1  \
# 335          gucci              NaN  Accessories & Jewellery
#
#              Category_2   Followers        Country    Likes  Comments
# 335  Clothing & Outfits  48700000.0  United States  33100.0   45100.0

# %%
data_cat = data_n3[(data_n3['Category_2'] == 'Music') | (data_n3['Category_1'] == 'Music')]
data_cat.nlargest(5, 'Followers').drop_duplicates()
# Out:
#     instagram name influencer name  Category_1                 Category_2  \
# 825    selenagomez     Selena Gomez      Music                  Lifestyle
# 124        beyonce        BeyonceÌ      Music                    Fashion
# 446            jlo   Jennifer Lopez      Music  Cinema & Actors/actresses
# 377      iamcardib          Cardi B      Music                    Fashion
# 849      snoopdogg        snoopdogg  Lifestyle                      Music
#
#        Followers        Country      Likes   Comments
# 825  330600000.0  United States  1200000.0  1600000.0
# 124  265000000.0  United States   922600.0  1300000.0
# 446  215500000.0  United States   700000.0   896200.0
# 377  135600000.0  United States  1200000.0  1700000.0
# 849   74400000.0  United States    31600.0    42800.0

# %%
data_cat = data_n3[(data_n3['Category_2'] == 'Sports with a ball') | (data_n3['Category_1'] == 'Sports with a ball')]
data_cat.nlargest(5, 'Followers').drop_duplicates()
# Out:
#       instagram name        influencer name           Category_1  \
# 548         leomessi               Leo Messi  Sports with a ball
# 213     davidbeckham           David Beckham              Family
# 699     nikefootball  Nike Football (Soccer)  Sports with a ball
# 873   stephencurry30           Wardell Curry  Sports with a ball
# 806  sachintendulkar        Sachin Tendulkar  Sports with a ball
#
#              Category_2    Followers        Country      Likes   Comments
# 548              Family  341700000.0      Argentina  4700000.0  6300000.0
# 213  Sports with a ball   74300000.0          India   272900.0   346400.0
# 699  Clothing & Outfits   45100000.0         Brazil   108200.0   165500.0
# 873              Family   44100000.0  United States   442800.0   591300.0
# 806           Lifestyle   34900000.0          India   204100.0   243000.0

# %% [markdown]
# Country vice followers sum

# %%
data_con = data_n3.groupby('Country')['Followers'].sum().sort_values(ascending=False)
data_con
# Out:
# Country
# United States     4.736200e+09
# India             1.617500e+09
# Brazil            9.009000e+08
# Indonesia         4.950000e+08
# Argentina         4.341000e+08
# Mexico            1.471000e+08
# Russia            7.130000e+07
# Iran              6.690000e+07
# Philippines       5.940000e+07
# Colombia          5.820000e+07
# Egypt             5.670000e+07
# Turkey            5.560000e+07
# South Korea       5.010000e+07
# Italy             4.290000e+07
# 1Unknown.2M       3.590000e+07
# Thailand          2.400000e+07
# United Kingdom    2.310000e+07
# Iraq              1.500000e+07
# Germany           8.300000e+06
# France            7.900000e+06
# Spain             7.300000e+06
# Unknown           5.700000e+06
# Name: Followers, dtype: float64

# %% [markdown]
# Top 5 followers in india

# %%
data_cat = data_n3[(data_n3['Country'] == 'India')]
data_cat.nlargest(5, 'Followers').drop_duplicates()
# Out:
#     instagram name influencer name                  Category_1  \
# 914        therock          therock  Cinema & Actors/actresses
# 669           nasa             NASA                    Science
# 213   davidbeckham    David Beckham                     Family
# 667   narendramodi    Narendra Modi        Finance & Economics
# 880     sunnyleone      Sunny Leone                     Beauty
#
#                     Category_2    Followers Country      Likes   Comments
# 914              Fitness & Gym  324200000.0   India   542300.0   711900.0
# 669                Photography   78300000.0   India   612100.0   734300.0
# 213         Sports with a ball   74300000.0   India   272900.0   346400.0
# 667         Business & Careers   68100000.0   India  1200000.0  1400000.0
# 880  Cinema & Actors/actresses   53000000.0   India   137600.0   188900.0

# %% [markdown]
# Person with max followers

# %%
data[data['Followers'] == data['Followers'].max()]
# Out:
#     instagram name influencer name    Category_1 Category_2    Followers  \
# 395      instagram        Instagram  Photography       Null  523300000.0
#
#     Country     Likes  Comments
# 395   India  294300.0  356500.0

# %% [markdown]
# Category vice person count

# %%
data_cat2.groupby('Category_1')['instagram name'].count().sort_values(ascending=False)
# Out:
# Category_1
# Music                                239
# Cinema & Actors/actresses            195
# Lifestyle                            138
# Sports with a ball                   122
# Null                                  95
# Shows                                 46
# Modeling                              33
# Beauty                                26
# Humor & Fun & Happiness               21
# Art/Artists                           13
# Family                                13
# Computers & Gadgets                   10
# Fashion                                8
# Adult content                          8
# Fitness & Gym                          7
# Racing Sports                          5
# Cars & Motorbikes                      5
# Finance & Economics                    5
# Literature & Journalism                5
# Photography                            4
# Food & Cooking                         4
# Business & Careers                     4
# ...

# %% [markdown]
# #Matplotlib, Seaborn, Statistics,Correlation
#
# ---

# %% [markdown]
# Corelation Graph

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="rainbow_r")
# Out:
# <Axes: >

# %%
plt.scatter(data['Comments'], data['Likes'])
plt.xlabel('Comments')
plt.ylabel('Likes')
plt.show()

# %% [markdown]
# indicating a very strong positive monotonic relationship between the two variables

# %%
r = np.corrcoef(data["Likes"], data["Comments"])[0, 1]
r
# Out:
# 0.8333313017341836

# %%
top5_followers = data.nlargest(5, 'Followers')
top5_followers
# Out:
#     instagram name   influencer name           Category_1 Category_2  \
# 395      instagram          Instagram         Photography       Null
# 197      cristiano  Cristiano Ronaldo  Sports with a ball       Null
# 524    kyliejenner         Kylie ðŸ¤             Fashion   Modeling
# 548       leomessi          Leo Messi  Sports with a ball     Family
# 825    selenagomez       Selena Gomez               Music  Lifestyle
#
#        Followers        Country      Likes   Comments
# 395  523300000.0          India   294300.0   356500.0
# 197  459200000.0          India  5100000.0  6200000.0
# 524  352700000.0  United States  2800000.0  4600000.0
# 548  341700000.0      Argentina  4700000.0  6300000.0
# 825  330600000.0  United States  1200000.0  1600000.0

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x='influencer name ', y='Followers', data=top5_followers, palette='viridis')
plt.xlabel('influencer name')
plt.ylabel('Followers')
plt.title('Top 5 Influencers by Number of Followers')
plt.show()
# Out:
# <ipython-input-26-3e16cbcba277>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='influencer name ', y='Followers', data=top5_followers, palette='viridis')
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 141 (\x8d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
top5_Likes = data.nlargest(5, 'Likes')
top5_Likes
# Out:
#     instagram name       influencer name    Category_1  \
# 920            thv                      V    Lifestyle
# 404            j.m                  JIMIN         Null
# 32          agustd  SUGA of BTS ë¯¼ìœ¤ê¸°    Lifestyle
# 940      uarmyhope                  jhope  Art/Artists
# 443            jin             Jin of BTS         Null
#
#                     Category_2   Followers        Country       Likes  \
# 920                       Null  44800000.0  United States  13200000.0
# 404                       Null  37000000.0          11.8M  11800000.0
# 32                       Music  35900000.0    1Unknown.2M  10200000.0
# 940  Cinema & Actors/actresses  36600000.0    South Korea   9400000.0
# 443                       Null  36600000.0  United States   9300000.0
#
#        Comments
# 920  13200000.0
# 404         0.0
# 32          0.0
# 940   9400000.0
# 443   9300000.0

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x='influencer name ', y='Likes', data=top5_Likes, palette='viridis')
plt.xlabel('influencer name')
plt.ylabel('Likes')
plt.title('Top 5 Influencers by Number of Likes')
plt.show()
# Out:
# <ipython-input-28-470d9144b335>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='influencer name ', y='Likes', data=top5_Likes, palette='viridis')

# %%
top5_Comments = data.nlargest(5, 'Comments')
top5_Comments
# Out:
#       instagram name influencer name                  Category_1  \
# 920              thv                V                  Lifestyle
# 940        uarmyhope            jhope                Art/Artists
# 443              jin       Jin of BTS                       Null
# 1016         zendaya          Zendaya  Cinema & Actors/actresses
# 427   jennierubyjane                J                      Music
#
#                      Category_2    Followers        Country       Likes  \
# 920                        Null   44800000.0  United States  13200000.0
# 940   Cinema & Actors/actresses   36600000.0    South Korea   9400000.0
# 443                        Null   36600000.0  United States   9300000.0
# 1016                    Fashion  146300000.0  United States   6300000.0
# 427                        Null   67600000.0      Indonesia   7000000.0
#
#         Comments
# 920   13200000.0
# 940    9400000.0
# 443    9300000.0
# 1016   8500000.0
# 427    8400000.0

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x='influencer name ', y='Comments', data=top5_Comments, palette='viridis')
plt.xlabel('influencer name')
plt.ylabel('Comments')
plt.title('Top 5 Influencers by Number of Comments')
plt.show()
# Out:
# <ipython-input-30-78927065c498>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='influencer name ', y='Comments', data=top5_Comments, palette='viridis')

# %%
df = data.copy()

# %%
max = df['Followers'].max()
min = df['Followers'].min()
mean = df['Followers'].mean()
median = df['Followers'].median()
std_dev = df['Followers'].std()
var = df['Followers'].var()
skew = df['Followers'].skew()
kurt = df['Followers'].kurt()
print(f'max: {max}')
print(f'min: {min}')
print(f"mean: {mean}")
print(f'median: {median}')
print(f'standard deviation: {std_dev}')
print(f'variance: {var}')
print(f'skewness: {skew}')
print(f'kurtosis: {kurt}')
# Out:
# max: 523299999.99999994
# min: 2200000.0
# mean: 25621819.960861057
# median: 14100000.0
# standard deviation: 43075988.74638651
# variance: 1855540806478817.5
# skewness: 6.029292495828356
# kurtosis: 46.08657397007203

# %%
max_life = 1023
data_frame = pd.DataFrame({
    "mean":[mean for i in range(max_life)],
    "median":[median for i in range(max_life)],
    "std_dev":[std_dev for i in range(max_life)],
    "variance":[var for i in range(max_life)],
    "skewness":[skew for i in range(max_life)],
    "kurtosis":[kurt for i in range(max_life)]
})

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,3,1)
data_frame["variance"].plot()
plt.legend(["variance"])

plt.subplot(1,3,2)
data_frame["mean"].plot()
data_frame["median"].plot()
data_frame["std_dev"].plot()
plt.legend(["mean", "median", "std_dev"])

plt.subplot(1,3,3)
data_frame["skewness"].plot()
data_frame["kurtosis"].plot()
plt.legend(["skewness", "kurtosis"])
plt.show()

# %%
chunks = [df[i:i+100] for i in range(0, len(df), 100)]
skewness = [chunk['Followers'].skew() for chunk in chunks]
kurtosis = [chunk['Followers'].kurtosis() for chunk in chunks]
print(skewness)
print(kurtosis)
# Out:
# [7.54800607749173, 6.208231791444768, 3.2645930594579977, 8.347761328143726, 3.6119107516240048, 3.9744629452733746, 3.2880094216346074, 2.402803078083727, 5.932601659577337, 5.533986949570922, 3.326940447170194]
# [66.80501147796969, 44.721914937407306, 13.151449093105622, 76.84420704349571, 13.810827495577648, 15.897322278863733, 11.233461674441118, 8.431839366175351, 40.750653864991996, 36.31292123801183, 12.756082849577693]

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(np.arange(len(skewness)), skewness, color='teal', marker='o', linestyle='-')
plt.title('Frequency curve Of Skewness')
plt.xlabel('Chunk')
plt.ylabel('Skewness')

plt.subplot(1,2,2)
plt.plot(np.arange(len(kurtosis)), kurtosis, color='brown', marker='o', linestyle='-')
plt.title('Frequency curve Of Kurtosis')
plt.xlabel('Chunk')
plt.ylabel('Kurtosis')

plt.tight_layout()
plt.show()

# %%
max = df['Likes'].max()
min = df['Likes'].min()
mean = df['Likes'].mean()
median = df['Likes'].median()
std_dev = df['Likes'].std()
var = df['Likes'].var()
skew = df['Likes'].skew()
kurt = df['Likes'].kurt()
print(f'max: {max}')
print(f'min: {min}')
print(f"mean: {mean}")
print(f'median: {median}')
print(f'standard deviation: {std_dev}')
print(f'variance: {var}')
print(f'skewness: {skew}')
print(f'kurtosis: {kurt}')
# Out:
# max: 13200000.0
# min: 0.0
# mean: 588739.7260273972
# median: 331500.0
# standard deviation: 1004632.6977273445
# variance: 1009286857342.9219
# skewness: 6.902440247134003
# kurtosis: 63.57481248274557

# %%
max_life = 1023
data_frame = pd.DataFrame({
    "mean":[mean for i in range(max_life)],
    "median":[median for i in range(max_life)],
    "std_dev":[std_dev for i in range(max_life)],
    "variance":[var for i in range(max_life)],
    "skewness":[skew for i in range(max_life)],
    "kurtosis":[kurt for i in range(max_life)]
})

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,3,1)
data_frame["variance"].plot()
plt.legend(["variance"])

plt.subplot(1,3,2)
data_frame["mean"].plot()
data_frame["median"].plot()
data_frame["std_dev"].plot()
plt.legend(["mean", "median", "std_dev"])

plt.subplot(1,3,3)
data_frame["skewness"].plot()
data_frame["kurtosis"].plot()
plt.legend(["skewness", "kurtosis"])
plt.show()

# %%
chunks = [df[i:i+100] for i in range(0, len(df), 100)]
skewness = [chunk['Likes'].skew() for chunk in chunks]
kurtosis = [chunk['Likes'].kurtosis() for chunk in chunks]
print(skewness)
print(kurtosis)
# Out:
# [7.716658252230245, 3.774429084338115, 3.128265404334268, 1.7012806024835587, 4.803718750249234, 4.937221665750983, 1.8770277266018531, 3.0259634950895475, 3.657622615457938, 5.900275112545759, 3.5626772591009943]
# [68.53446826284993, 16.568458375590737, 12.379722224631951, 2.3441160885187275, 25.343100767980445, 29.20371672295066, 3.9726035636122092, 11.845418428869719, 19.787743708362097, 38.224203572062976, 13.6175449100096]

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(np.arange(len(skewness)), skewness, color='teal', marker='o', linestyle='-')
plt.title('Frequency curve Of Skewness')
plt.xlabel('Chunk')
plt.ylabel('Skewness')

plt.subplot(1,2,2)
plt.plot(np.arange(len(kurtosis)), kurtosis, color='brown', marker='o', linestyle='-')
plt.title('Frequency curve Of Kurtosis')
plt.xlabel('Chunk')
plt.ylabel('Kurtosis')

plt.tight_layout()
plt.show()

# %%
max = df['Comments'].max()
min = df['Comments'].min()
mean = df['Comments'].mean()
median = df['Comments'].median()
std_dev = df['Comments'].std()
var = df['Comments'].var()
skew = df['Comments'].skew()
kurt = df['Comments'].kurt()
print(f'max: {max}')
print(f'min: {min}')
print(f"mean: {mean}")
print(f'median: {median}')
print(f'standard deviation: {std_dev}')
print(f'variance: {var}')
print(f'skewness: {skew}')
print(f'kurtosis: {kurt}')
# Out:
# max: 13200000.0
# min: 0.0
# mean: 736330.2348336595
# median: 449050.0
# standard deviation: 1031376.1516468377
# variance: 1063736766185.8408
# skewness: 5.414829402257216
# kurtosis: 42.31276482838753

# %%
max_life = 1023
data_frame = pd.DataFrame({
    "mean":[mean for i in range(max_life)],
    "median":[median for i in range(max_life)],
    "std_dev":[std_dev for i in range(max_life)],
    "variance":[var for i in range(max_life)],
    "skewness":[skew for i in range(max_life)],
    "kurtosis":[kurt for i in range(max_life)]
})

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,3,1)
data_frame["variance"].plot()
plt.legend(["variance"])

plt.subplot(1,3,2)
data_frame["mean"].plot()
data_frame["median"].plot()
data_frame["std_dev"].plot()
plt.legend(["mean", "median", "std_dev"])

plt.subplot(1,3,3)
data_frame["skewness"].plot()
data_frame["kurtosis"].plot()
plt.legend(["skewness", "kurtosis"])
plt.show()

# %%
chunks = [df[i:i+100] for i in range(0, len(df), 100)]
skewness = [chunk['Comments'].skew() for chunk in chunks]
kurtosis = [chunk['Comments'].kurtosis() for chunk in chunks]
print(skewness)
print(kurtosis)
# Out:
# [2.5746681631807475, 3.6681920655124323, 2.943843751448658, 1.6907831652622924, 4.725092402528633, 4.296236699468723, 1.7817532192862726, 2.7940753698731458, 3.103942856573012, 5.361937672231872, 3.429595474425664]
# [8.693685103089262, 15.63151525896236, 10.668041680479385, 2.5502688528977884, 25.658820146139124, 20.959355057073147, 3.370506231197108, 9.736722173983114, 13.408926466332026, 32.312813211213346, 12.323682578109407]

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(np.arange(len(skewness)), skewness, color='teal', marker='o', linestyle='-')
plt.title('Frequency curve Of Skewness')
plt.xlabel('Chunk')
plt.ylabel('Skewness')

plt.subplot(1,2,2)
plt.plot(np.arange(len(kurtosis)), kurtosis, color='brown', marker='o', linestyle='-')
plt.title('Frequency curve Of Kurtosis')
plt.xlabel('Chunk')
plt.ylabel('Kurtosis')

plt.tight_layout()
plt.show()

# %%
sns.histplot(data['Followers'], bins=30, kde=True)
plt.title('Distribution of Followers')
plt.xlabel('Number of Followers')
plt.ylabel('Frequency')
plt.show()
