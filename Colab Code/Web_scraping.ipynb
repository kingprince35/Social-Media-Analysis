# %% [markdown]
# # Load Require Libries

# %%
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# # Load First Page

# %%
r = requests.get("https://keithgalli.github.io/web-scraping/example.html")
print(r) # Return to webpage content
soup = bs(r.content)  # it's Convert to Beatiful contents
print(soup.prettify())
# Out:
# <Response [200]>
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# # Beautifull Soup to Scrape
#
# **find and find_all**

# %%
first_header = soup.find("h1")
first_header

headers = soup.find_all("h2")
headers
# Out:
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
first_header = soup.find(["h2" , "h1"]) # it's saw h1 ,h2 ,h3....... List ni ander h2 pela lakhisu to h2 pela em nai ave ema khas dhyan rakhavu
first_header

headers = soup.find_all(["h1" , "h2"])
headers
# Out:
# [<h1>HTML Webpage</h1>, <h2>A Header</h2>, <h2>Another header</h2>]

# %% [markdown]
# **Pass attributes using find and find_all**

# %%
pr = soup.find_all("p",attrs={"id" : "paragraph-id"})
pr
# Out:
# [<p id="paragraph-id"><b>Some bold text</b></p>]

# %% [markdown]
# **find in nested blocks**

# %%
body = soup.find("body")
div = body.find("div")
header = div.find("h1")
header
# Out:
# <h1>HTML Webpage</h1>

# %% [markdown]
# *search any string*

# %%
import re
pr = soup.find_all("p" , string=re.compile("Some"))
pr

headers = soup.find_all("h2" , string=re.compile("(H|h)eader"))  # h\H means H or h...
headers
# Out:
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %% [markdown]
# ### Select CSS selection

# %%
body = soup.body
print(body.prettify())
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %%
content = soup.select("div p")
content
# Out:
# [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>]

# %%
pr = soup.select("h2 ~ p")
pr
# Out:
# [<p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
bold_text = soup.select("p#paragraph-id b")
bold_text

pr = soup.select("body > p")
print(pr)

for paragraph in pr:
  print(paragraph.select("i"))
# Out:
# [<p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
# [<i>Some italicized text</i>]
# []

# %% [markdown]
# ### Get Different properties of the HTML

# %%
# use .string
headers = soup.find("h2")
headers.string

# If multiple child element then use get_text()
div = soup.find("div")
print(div.prettify())
print(div.get_text())
# Out:
# <div align="middle">
#  <h1>
#   HTML Webpage
#  </h1>
#  <p>
#   Link to more interesting example:
#   <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#    keithgalli.github.io/web-scraping/webpage.html
#   </a>
#  </p>
# </div>
#
#
# HTML Webpage
# Link to more interesting example: keithgalli.github.io/web-scraping/webpage.html

# %%
link = soup.find("a")
link['href']

pr = soup.select("p#paragraph-id")
pr[0]['id']
# Out:
# 'paragraph-id'

# %%
# Path syntax
soup.body.div.h1.string
print(soup.body.prettify())
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %%
# know the terms : Parents , child , siblings
soup.body.find("div").find_next_siblings()
print(soup.find("div").find_parent().prettify())
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %% [markdown]
# ### Example -1

# %%
# first of all import request , impoert Beautifulsoup and load the data
r = requests.get("https://keithgalli.github.io/web-scraping/webpage.html")
webpage = bs(r.content)
print(webpage.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %% [markdown]
# ### Grab all the social links from the webpage

# %%
links = webpage.select("ul.socials a")
actual_links = [link['href'] for link in links]
actual_links
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %% [markdown]
# ### Scrap Table

# %%
import pandas as pd

table = webpage.select("table.hockey-stats")[0]
columns = table.find("thead").find_all("th")
column_names = [c.string for c in columns]
table_rows = table.find("tbody").find_all("tr")
l = []
for tr in table_rows:
  td = tr.find_all("td")
  row = [str(tr.get_text()).strip() for tr in td]
  l.append(row)
df = pd.DataFrame(l,columns = column_names)
# df.loc[df["Team"] != "Did not play"]
df
# Out:
#          S                        Team    League  GP  G   A  TP PIM +/-     \
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  12  20      |
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1   2   2      |
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  10   8   0  |
# 3  2017-18                Did not play                                   |
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  15   8      |
#
#   POST GP G A TP PIM +/-
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Grab all fun facts that use word "is"

# %%
facts = webpage.select("ul.fun-facts li")
facts_with_is = [fact.find_all(string = re.compile("is")) for fact in facts]
facts_with_is = [fact for fact in facts_with_is if fact]
facts_with_is
# Out:
# [['Middle name is Ronald'],
#  ['Dunkin Donuts coffee is better than Starbucks'],
#  ['A favorite book series of mine is '],
#  ['Current video game of choice is '],
#  ["The band that I've seen the most times live is the "]]

# %% [markdown]
# ### Download images

# %%
img = webpage.select("div.row div.column img")
img[0]['src']
# Out:
# 'images/italy/lake_como.jpg'

# %%
files = webpage.select("div.block a")
relative_files = [file['href'] for file in files]
url = "https://keithgalli.github.io/web-scraping/"
for f in relative_files:
  full_url = url+f
  page = requests.get(full_url)
  bs_page = bs(page.content)
  secret_word_element = bs_page.find("p" , attrs={"id" : "secret-word"})
  secret_word = secret_word_element.string
  print(secret_word)
# Out:
# Make
# sure
# to
# smash
# that
# like
# button
# and
# subscribe
# !!!
