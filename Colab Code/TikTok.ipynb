# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
table=pd.read_csv('Tiktok.csv')

# %%
table.head(25)
table1=table.copy()
table1
# Out:
#         Tiktoker name  Subscribers      Views     Likes  Comments  Shares  \
# 0           ...anddy_    1100000.0   937100.0  141900.0    7300.0   792.0
# 1            .02h.88m    1200000.0   917800.0  172600.0    1600.0  2400.0
# 2           .jmwalton    1200000.0  3400000.0  667000.0   15300.0  5600.0
# 3     _.anime.edits_0      97000.0  1700000.0   75600.0    1500.0  8700.0
# 4     _.anime.edits_0      97000.0  1700000.0   75600.0    1500.0  8700.0
# ...               ...          ...        ...       ...       ...     ...
# 4993    nicolebernaal    4000000.0  2200000.0  351300.0     957.0   195.0
# 4994    bellaretamosa    5100000.0  2500000.0  340400.0     901.0   145.0
# 4995         tunico80    5800000.0  1000000.0  206800.0    2000.0  2100.0
# 4996     armon.warren    1200000.0  1900000.0  300800.0     904.0   630.0
# 4997  soanhvadiephihi    1600000.0  2600000.0  273200.0     720.0   530.0
#
#       Month
# 0         9
# 1         9
# 2         6
# 3         9
# ...

# %%
table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4998 entries, 0 to 4997
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tiktoker name  4998 non-null   object
#  1   Subscribers    4998 non-null   float64
#  2   Views          4998 non-null   float64
#  3   Likes          4998 non-null   float64
#  4   Comments       4998 non-null   float64
#  5   Shares         4998 non-null   float64
#  6   Month          4998 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 273.5+ KB

# %%
table1[table1['Subscribers']>97000.0]
# Out:
#          Tiktoker name  Subscribers      Views     Likes  Comments  Shares  \
# 0            ...anddy_    1100000.0   937100.0  141900.0    7300.0   792.0
# 1             .02h.88m    1200000.0   917800.0  172600.0    1600.0  2400.0
# 2            .jmwalton    1200000.0  3400000.0  667000.0   15300.0  5600.0
# 5     _.respect.boss._    1500000.0  4400000.0  241900.0     249.0   797.0
# 6     _.the.meme.hub._    2300000.0  3800000.0  787700.0    2900.0  9000.0
# ...                ...          ...        ...       ...       ...     ...
# 4993     nicolebernaal    4000000.0  2200000.0  351300.0     957.0   195.0
# 4994     bellaretamosa    5100000.0  2500000.0  340400.0     901.0   145.0
# 4995          tunico80    5800000.0  1000000.0  206800.0    2000.0  2100.0
# 4996      armon.warren    1200000.0  1900000.0  300800.0     904.0   630.0
# 4997   soanhvadiephihi    1600000.0  2600000.0  273200.0     720.0   530.0
#
#       Month
# 0         9
# 1         9
# 2         6
# 5         6
# ...

# %% [markdown]
# **Top 5 Name with respect to Views**

# %%
max_views=table1.nlargest(5,'Views')
max_views
# Out:
#      Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 3642     sehataqua     533200.0  61100000.0    70000.0     539.0   1300.0
# 196       badbunny   22200000.0  48900000.0  9000000.0   58400.0  96700.0
# 3981         yzn47    8900000.0  48900000.0   998400.0   16300.0  60900.0
# 4115    tiktokmena    5700000.0  39500000.0   179200.0    1200.0   2200.0
# 3317       mrbeast   55600000.0  38100000.0  3800000.0   19000.0   7800.0
#
#       Month
# 3642     11
# 196       6
# 3981     12
# 4115      0
# 3317     11

# %% [markdown]
# **Top 5 Name with respect to subscribers**

# %%
max_subscribers=table1.nlargest(5,'Subscribers')
max_subscribers
# Out:
#       Tiktoker name  Subscribers       Views      Likes  Comments  Shares  \
# 3020     khaby.lame  153100000.0  10600000.0  1200000.0   20800.0  2300.0
# 3021     khaby.lame  152000000.0  15000000.0  1800000.0    6500.0  3200.0
# 994      khaby.lame  149200000.0  17300000.0  2300000.0   15200.0  8700.0
# 2330  charlidamelio  149000000.0   7800000.0   789900.0    6900.0  3000.0
# 2331  charlidamelio  148400000.0   8600000.0   641900.0    9700.0  2500.0
#
#       Month
# 3020     12
# 3021     11
# 994       9
# 2330     12
# 2331     11

# %% [markdown]
# **Top 5 Name with  respect to Likes**

# %%
max_Likes=table1.nlargest(5,'Likes')
max_Likes
# Out:
#      Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 196       badbunny   22200000.0  48900000.0  9000000.0   58400.0  96700.0
# 4001       dojacat   22200000.0  25400000.0  5000000.0   36700.0  46800.0
# 1404   noahschnapp   23700000.0  23600000.0  4900000.0   44200.0  16000.0
# 4005      badbunny   16100000.0  17600000.0  4000000.0   28000.0  26200.0
# 3317       mrbeast   55600000.0  38100000.0  3800000.0   19000.0   7800.0
#
#       Month
# 196       6
# 4001      0
# 1404      6
# 4005      0
# 3317     11

# %% [markdown]
# **Top 5 Name with  respect to Comments**

# %%
max_comments=table1.nlargest(5,'Comments')
max_comments
# Out:
#        Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 3943     xelitobelek    1200000.0   2500000.0   336700.0   64800.0    192.0
# 594          enhypen   11800000.0   8000000.0  2400000.0   63000.0  40600.0
# 196         badbunny   22200000.0  48900000.0  9000000.0   58400.0  96700.0
# 4003   charlidamelio  135400000.0  18700000.0  2600000.0   54700.0  35200.0
# 1643  scarlettsspam2    2100000.0  17900000.0   845800.0   53900.0   6300.0
#
#       Month
# 3943     12
# 594       6
# 196       6
# 4003      0
# 1643      9

# %% [markdown]
# **Top 5 Name with  respect to shares**

# %%
max_shares=table1.nlargest(5,'Shares')
max_shares
# Out:
#       Tiktoker name  Subscribers       Views      Likes  Comments    Shares  \
# 4448  tatiana1964_2      31000.0   1700000.0    12400.0     207.0  151800.0
# 400       codsterss      58000.0  13000000.0   951600.0   13200.0  136000.0
# 4000       ekin.721     221700.0  26000000.0  2800000.0   29400.0  116400.0
# 196        badbunny   22200000.0  48900000.0  9000000.0   58400.0   96700.0
# 2693        hf37777     801500.0   1300000.0    85200.0    4300.0   80400.0
#
#       Month
# 4448      0
# 400       6
# 4000      0
# 196       6
# 2693     12

# %% [markdown]
# **Name more than 20cr subscribers in month 9**

# %%
table1[(table1['Subscribers']>20000000) & (table1['Month']==9)]
# Out:
#         Tiktoker name  Subscribers       Views     Likes  Comments   Shares  \
# 63          addisonre   88700000.0  22000000.0  906600.0    7600.0  26200.0
# 140    angryreactions   26600000.0   1500000.0  257100.0    1300.0    376.0
# 159      arigameplays   23200000.0   2800000.0  320700.0    1400.0    867.0
# 208    bayashi.tiktok   33600000.0   4400000.0  492000.0    2600.0    786.0
# 222       bellapoarch   91400000.0   7400000.0  677300.0    4900.0   1100.0
# ...               ...          ...         ...       ...       ...      ...
# 1888    vanessalopesr   25200000.0   3400000.0  327800.0    3600.0   1900.0
# 1900       victormelo   21900000.0   4500000.0  736700.0    2500.0   4200.0
# 1919  virginiafonseca   34100000.0   3000000.0  410900.0    1200.0    961.0
# 1934       wigofellas   34400000.0   2600000.0  158900.0    1900.0   1200.0
# 1950           xoteam   37800000.0   2500000.0  180200.0     859.0    450.0
#
#       Month
# 63        9
# 140       9
# 159       9
# ...

# %%
month_9=table1[table1['Month']==9]
month_6=table1[table1['Month']==6]
month_11=table1[table1['Month']==11]
month_12=table1[table1['Month']==12]
month_0=table1[table1['Month']==0]

# %% [markdown]
# **Top 10 Name with  respect to subscribes in month wise**

# %%
max_subscribers=month_9.nlargest(10,'Subscribers')
max_subscribers
# Out:
#         Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 994        khaby.lame  149200000.0  17300000.0  2300000.0   15200.0   8700.0
# 362     charlidamelio  146200000.0  15200000.0   959400.0   20800.0   4600.0
# 222       bellapoarch   91400000.0   7400000.0   677300.0    4900.0   1100.0
# 63          addisonre   88700000.0  22000000.0   906600.0    7600.0  26200.0
# 1006  kimberly.loaiza   67200000.0   8800000.0  1200000.0   12100.0   4300.0
# 432          cznburak   63600000.0   4600000.0   228400.0    2300.0    978.0
# 516          domelipa   58100000.0  10400000.0  1500000.0    9100.0   3500.0
# 509      dixiedamelio   57400000.0   2400000.0   220500.0    1900.0    424.0
# 1826          therock   55400000.0  13100000.0  1500000.0   14300.0  11900.0
# 1142        lorengray   54600000.0   3100000.0   358700.0     879.0    761.0
#
#       Month
# 994       9
# 362       9
# 222       9
# 63        9
# 1006      9
# 432       9
# 516       9
# 509       9
# ...

# %%
max_subscribers=month_6.nlargest(10,'Subscribers')
max_subscribers
# Out:
#         Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 995        khaby.lame  143200000.0  25300000.0  2900000.0   23500.0  16300.0
# 363     charlidamelio  142000000.0  16400000.0  1800000.0   27300.0   9500.0
# 223       bellapoarch   90200000.0   6800000.0   921900.0    9500.0   1200.0
# 64          addisonre   88000000.0   7500000.0   704300.0    4300.0   2000.0
# 1984         zachking   68800000.0   3500000.0   394400.0    1400.0    650.0
# 1007  kimberly.loaiza   64200000.0   6300000.0  1000000.0   11500.0   2600.0
# 433          cznburak   59500000.0   4300000.0   288900.0    1600.0    927.0
# 517          domelipa   54200000.0   8600000.0  1500000.0   14300.0   4100.0
# 1827          therock   53100000.0   2700000.0   422700.0    5900.0   2900.0
# 1463          ox_zung   45000000.0   1900000.0   258300.0    2300.0    564.0
#
#       Month
# 995       6
# 363       6
# 223       6
# 64        6
# 1984      6
# 1007      6
# 433       6
# 517       6
# ...

# %%
max_subscribers=month_11.nlargest(10,'Subscribers')
max_subscribers
# Out:
#         Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 3021       khaby.lame  152000000.0  15000000.0  1800000.0    6500.0   3200.0
# 2331    charlidamelio  148400000.0   8600000.0   641900.0    9700.0   2500.0
# 2051        addisonre   88700000.0   6800000.0   523200.0    2500.0   3800.0
# 3985         zachking   70700000.0   9300000.0   591000.0    1100.0   1400.0
# 3029  kimberly.loaiza   69300000.0   7700000.0   868000.0    6200.0   1900.0
# 3824          therock   63200000.0   6400000.0   689800.0   10800.0   4100.0
# 2481         domelipa   60500000.0   9100000.0  1200000.0    6000.0   2700.0
# 2472     dixiedamelio   57500000.0   3000000.0   101300.0    1300.0    361.0
# 2844      jasonderulo   56100000.0   3400000.0   225500.0     561.0  15800.0
# 3317          mrbeast   55600000.0  38100000.0  3800000.0   19000.0   7800.0
#
#       Month
# 3021     11
# 2331     11
# 2051     11
# 3985     11
# 3029     11
# 3824     11
# 2481     11
# 2472     11
# ...

# %%
max_subscribers=month_12.nlargest(10,'Subscribers')
max_subscribers
# Out:
#         Tiktoker name  Subscribers       Views      Likes  Comments  Shares  \
# 3020       khaby.lame  153100000.0  10600000.0  1200000.0   20800.0  2300.0
# 2330    charlidamelio  149000000.0   7800000.0   789900.0    6900.0  3000.0
# 2212      bellapoarch   92600000.0   6000000.0   482200.0    4800.0  1500.0
# 2050        addisonre   88700000.0   5300000.0   304900.0    2400.0  2000.0
# 3932        willsmith   73000000.0   4700000.0   514600.0    2200.0  2000.0
# 3984         zachking   72100000.0  11500000.0   466400.0    1600.0  1500.0
# 3028  kimberly.loaiza   70200000.0   7700000.0   883300.0    8800.0  3900.0
# 2399         cznburak   66300000.0   3200000.0   205100.0    1700.0   681.0
# 3823          therock   64300000.0   3600000.0   626000.0    8000.0  7800.0
# 2480         domelipa   62000000.0   5800000.0   779900.0    5300.0  2500.0
#
#       Month
# 3020     12
# 2330     12
# 2212     12
# 2050     12
# 3932     12
# 3984     12
# 3028     12
# 2399     12
# ...

# %%
max_subscribers=month_0.nlargest(10,'Subscribers')
max_subscribers
# Out:
#         Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 4003    charlidamelio  135400000.0  18700000.0  2600000.0   54700.0  35200.0
# 4006       khaby.lame  135200000.0  17700000.0  2300000.0   18000.0  11200.0
# 4031      bellapoarch   88500000.0  11100000.0  1000000.0   14300.0   1600.0
# 4027        addisonre   87300000.0   9300000.0  1200000.0   13400.0   5900.0
# 4063        willsmith   67400000.0   6900000.0   658500.0   10000.0   2000.0
# 4022  kimberly.loaiza   61000000.0   9900000.0  1300000.0   14100.0   4500.0
# 4280     dixiedamelio   57200000.0   4400000.0   275200.0    4600.0   1100.0
# 4842        lorengray   54300000.0   1800000.0   248400.0    1500.0   1200.0
# 4025         domelipa   50700000.0   7900000.0  1200000.0   17300.0   6200.0
# 4074       kallmekris   43300000.0   5400000.0   988000.0    5500.0   3100.0
#
#       Month
# 4003      0
# 4006      0
# 4031      0
# 4027      0
# 4063      0
# 4022      0
# 4280      0
# 4842      0
# ...

# %% [markdown]
# **<h1>Matplotlib, Seaborn, Statistics</h1>**

# %%
sns.heatmap(table.corr(numeric_only=True), annot=True, cmap="rainbow_r")
# Out:
# <Axes: >

# %% [markdown]
# **<h2>The heatmap displays the correlation between various metrics: Subscribers, Views, Likes, Comments, Shares, and Month. Key observations are:
#
# Views and Likes have a strong positive correlation (0.73), indicating that as views increase, likes tend to increase as well.
# Likes and Comments also show a moderate positive correlation (0.57).
# There are weak or negligible correlations between Month and the other metrics, suggesting that monthly variations don't significantly</h2>**

# %%
plt.scatter(table['Comments'], table['Likes'])
plt.xlabel('Comments')
plt.ylabel('Likes')
plt.show()

# %%
top5_subscribers = table.nlargest(5, 'Subscribers')
top5_subscribers
# Out:
#       Tiktoker name  Subscribers       Views      Likes  Comments  Shares  \
# 3020     khaby.lame  153100000.0  10600000.0  1200000.0   20800.0  2300.0
# 3021     khaby.lame  152000000.0  15000000.0  1800000.0    6500.0  3200.0
# 994      khaby.lame  149200000.0  17300000.0  2300000.0   15200.0  8700.0
# 2330  charlidamelio  149000000.0   7800000.0   789900.0    6900.0  3000.0
# 2331  charlidamelio  148400000.0   8600000.0   641900.0    9700.0  2500.0
#
#       Month
# 3020     12
# 3021     11
# 994       9
# 2330     12
# 2331     11

# %%
plt.figure(figsize=(15, 6))
sns.barplot( x='Tiktoker name', y='Subscribers', data=top5_subscribers, palette='viridis',hue='Month')
plt.xlabel('Tiktoker name')
plt.ylabel('Subscribers')
plt.title('Top 5 Influencers by Number of Subscribers')
plt.show()

# %%
top5_Likes = table.nlargest(5, 'Likes')
top5_Likes
# Out:
#      Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 196       badbunny   22200000.0  48900000.0  9000000.0   58400.0  96700.0
# 4001       dojacat   22200000.0  25400000.0  5000000.0   36700.0  46800.0
# 1404   noahschnapp   23700000.0  23600000.0  4900000.0   44200.0  16000.0
# 4005      badbunny   16100000.0  17600000.0  4000000.0   28000.0  26200.0
# 3317       mrbeast   55600000.0  38100000.0  3800000.0   19000.0   7800.0
#
#       Month
# 196       6
# 4001      0
# 1404      6
# 4005      0
# 3317     11

# %%
plt.figure(figsize=(15, 6))
sns.barplot( x='Tiktoker name', y='Likes', data=top5_Likes, palette='viridis')
plt.xlabel('Tiktoker name')
plt.ylabel('Likes')
plt.title('Top 5 Influencers by Number of Likes')
plt.show()
# Out:
# <ipython-input-23-0ed6ad5990ab>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( x='Tiktoker name', y='Likes', data=top5_Likes, palette='viridis')

# %%
top5_Comments = table.nlargest(5, 'Comments')
top5_Comments
# Out:
#        Tiktoker name  Subscribers       Views      Likes  Comments   Shares  \
# 3943     xelitobelek    1200000.0   2500000.0   336700.0   64800.0    192.0
# 594          enhypen   11800000.0   8000000.0  2400000.0   63000.0  40600.0
# 196         badbunny   22200000.0  48900000.0  9000000.0   58400.0  96700.0
# 4003   charlidamelio  135400000.0  18700000.0  2600000.0   54700.0  35200.0
# 1643  scarlettsspam2    2100000.0  17900000.0   845800.0   53900.0   6300.0
#
#       Month
# 3943     12
# 594       6
# 196       6
# 4003      0
# 1643      9

# %%
plt.figure(figsize=(15, 6))
sns.barplot( x='Tiktoker name', y='Comments', data=top5_Comments, palette='viridis')
plt.xlabel('Tiktoker name')
plt.ylabel('Commentd')
plt.title('Top 5 Influencers by Number of Comments')
plt.show()
# Out:
# <ipython-input-25-be618d906b7f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( x='Tiktoker name', y='Comments', data=top5_Comments, palette='viridis')

# %%
max = table['Subscribers'].max()
min = table['Subscribers'].min()
mean = table['Subscribers'].mean()
median = table['Subscribers'].median()
std_dev = table['Subscribers'].std()
var = table['Subscribers'].var()
print(f'max: {max}')
print(f'min: {min}')
print(f"mean: {mean}")
print(f'median: {median}')
print(f'standard deviation: {std_dev}')
print(f'variance: {var}')
# Out:
# max: 153100000.0
# min: 2100.0
# mean: 7432019.587835134
# median: 3900000.0
# standard deviation: 11482766.775514994
# variance: 131853932820871.0

# %%
max_life = 1023
data_frame = pd.DataFrame({
    "mean":[mean for i in range(max_life)],
    "median":[median for i in range(max_life)],
    "std_dev":[std_dev for i in range(max_life)],
    "variance":[var for i in range(max_life)],
    })

# %%
plt.figure(figsize = (15,7))

plt.subplot(2,3,1)
data_frame["variance"].plot()
plt.legend(["variance"])

plt.subplot(2,3,2)
data_frame["mean"].plot()
data_frame["median"].plot()
data_frame["std_dev"].plot()
plt.legend(["mean", "median", "std_dev"])

# %%
max = table['Likes'].max()
min = table['Likes'].min()
mean = table['Likes'].mean()
median = table['Likes'].median()
std_dev = table['Likes'].std()
var = table['Likes'].var()
print(f'max: {max}')
print(f'min: {min}')
print(f"mean: {mean}")
print(f'median: {median}')
print(f'standard deviation: {std_dev}')
print(f'variance: {var}')
# Out:
# max: 9000000.0
# min: 12400.0
# mean: 363118.9675870348
# median: 274100.0
# standard deviation: 350399.6883350865
# variance: 122779941585.32574

# %%
max_life = 1023
data_frame = pd.DataFrame({
    "mean":[mean for i in range(max_life)],
    "median":[median for i in range(max_life)],
    "std_dev":[std_dev for i in range(max_life)],
    "variance":[var for i in range(max_life)],
    })

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,3,1)
data_frame["variance"].plot()
plt.legend(["variance"])

plt.subplot(1,3,2)
data_frame["mean"].plot()
data_frame["median"].plot()
data_frame["std_dev"].plot()
plt.legend(["mean", "median", "std_dev"])

# %%
max = table['Comments'].max()
min = table['Comments'].min()
mean = table['Comments'].mean()
median = table['Comments'].median()
std_dev = table['Comments'].std()
var = table['Comments'].var()
print(f'max: {max}')
print(f'min: {min}')
print(f"mean: {mean}")
print(f'median: {median}')
print(f'standard deviation: {std_dev}')
print(f'variance: {var}')
# Out:
# max: 64800.0
# min: 3.0
# mean: 2691.2549019607845
# median: 1700.0
# standard deviation: 3958.2279833673006
# variance: 15667568.768311966

# %%
max_life = 1023
data_frame = pd.DataFrame({
    "mean":[mean for i in range(max_life)],
    "median":[median for i in range(max_life)],
    "std_dev":[std_dev for i in range(max_life)],
    "variance":[var for i in range(max_life)],
    })

# %%
plt.figure(figsize = (15,7))

plt.subplot(1,3,1)
data_frame["variance"].plot()
plt.legend(["variance"])

plt.subplot(1,3,2)
data_frame["mean"].plot()
data_frame["median"].plot()
data_frame["std_dev"].plot()
plt.legend(["mean", "median", "std_dev"])
